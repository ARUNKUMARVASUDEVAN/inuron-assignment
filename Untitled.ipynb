# %% [markdown]
# 1. What exactly is []?
#
# Ans:
#   [] is an empty list or a lis without any elements we can insert values init
#
#
# 2.In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the
# third value? (Assume [2, 4, 6, 8, 10] are in spam.)
#
#
# Ans:
# spam=[2,4,6,8,10]
# in the place of 6  this &#39;hello&#39; number is added by using insert() function.
#
# spam.insert(2,'&#39;hello&#39;')
#
# output==[2, 4, '&#39;hello&#39;', 6, 8, 10]
#
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
#
# ans:
# the above expression
# expression gives output as 3 lets put like spam[3]==6
#
# 4. What is the value of spam[-1]?
#
# ans:
# spam=[2, 4, '&#39;hello&#39;', 6, 8, 10,'a','b','c','d']
# spam[-1]='d'
#
# 5. What is the value of spam[:2]?
# ans:
# spam[:2] it will print first two elements of spam list.
#
# here first two elements will are [2,4]
#
# 6. What is the value of bacon.index('cat')?
# ans:
# bacon=[3.14,'cat','11',True]
# bacon.index('cat')==1
#
# 7. How does bacon.append(99) change the look of the list value in bacon?
#
# Ans:
# it will add the 99 on the bottom of list
# bacon=[3.14,'cat','11',True,99]
#
# 8. How does bacon.remove(&#39;cat&#39;) change the look of the list in bacon?
# ans:
# it removes the first cat in the bacon list
# bacon=[3.14, '11', 'cat', True]
#
# 9. What are the list concatenation and list replication operators?
# ans:
# list concatenation will done by '+' operator and replication is done by '*' operator
#
#
# 10. What is difference between the list methods append() and insert()?
#
# ans:
#
# append() function will only concat or add the elements in the bottom of a list
#
# insert() function that helps to add the elements to the list wherever we want in a list,It takes the position and elements on the input
#
# 11. What are the two methods for removing items from a list?
#
# ans:
# two methods pop() and remove()
#
# pop() takes the index of the element and deletes the element
#
# remove() takes the exact element in a list and remove the element
#
# 12. Describe how list values and string values are identical.
#
# ans:
# both are sequences,both can be indexed and and sliced,both support '*','+', in and not in operations.Both are iterable
#
# 13. What is the difference between tuples and lists?
#
# ans:
#
# list is mutable and tuples are immutable
# list use square brackets and tuples use paranthesis
# list can have man number of elements and tuples have fixed length of elements
# list consume more memory than tuples
#
# 14. How do you type a tuple value that only contains the integer 42?
# ans:
# t=(42,)
#
# 15. How do you get a list value's tuple form? How do you get a tuple value's list form?
# ans:
# type conversion is used if list from tuple can be achieved by list(tuple)
#
# and  tuple can be achieved by tuple(list)
#
# 16. Variables that'contain' list values are not necessarily lists themselves. Instead, what do they
# contain?
#
# ans:
# variable contain the the list actually it reference the list object in memory not the exact list.but if we change the variable it changes the list also
#
#
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?
# ans:
# both are from copy library when copy.copy() it copies the list and stored in new storage  if any changes persists in the copied file it will reflect the original file and then deepcopy() is used it also copy the file and store the file in new location if any changes inside the file cannot impact in the original file
