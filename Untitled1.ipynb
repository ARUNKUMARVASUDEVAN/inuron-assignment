# %% [raw]
# 1. What does an empty dictionary's code look like?
#
# ans:
#
# empty dictionary look like
#
# my_dict={}
#
# if we want add any value into the dictionary my_dict['key1']='value'
#
#
# 2. What is the value of a dictionary value with the key 'foo' and the
# value 42?
#
# ans:
#
# my_dict={'foo':42}
#
# it have single value so the entire dictionary will have only one value then its value should be 42
#
# 3. What is the most significant distinction between a dictionary and a list?
#
# ans:
#
# when a list only store the values ,the dictionary stores the key and value pairs.If we want to access the value in the list we can retrieve with the help of index.When it is come to dictionary we can access through the key's.
#
# 4. What happens if you try to access spam[&#39;foo&#39;] if spam is {'bar';: 100}?
#
# ans:
#
# it gives key error
#
# 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?
#
# ans:
#
# 'cat' in spam it return true if the word cat is there on the dictionary,
# 'cat' in spam.keys() it return true when the dictionary have the key in the name of 'cat'
#
#
# 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and
# 'cat' in spam.values()?
#
# ans:
#
# 'cat' in spam it return true if the word cat is there on the dictionary,
#
# 'cat' in spam.values() it return true when the dictionary have the value in the name of 'cat'
#
# 7. What is a shortcut for the following code?
# if 'color' not in spam:
# spam[color] = black
#
# ans;
# spam.setdefault('color','black')
#
#
# 8. How do you 'pretty print' dictionary values using which module and function?
#
# ans:
#
# we can get pretty print in pprint module and we can use pprint() function.
