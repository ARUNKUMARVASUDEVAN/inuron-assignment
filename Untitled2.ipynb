# %% [raw]
# 1. What are escape characters, and how do you use them?
# ans:
#
# Escape characters are special characters that are used in a programming language to include characters like new line,tab and marks
#
# \n:newline,
# \t:tab,
# ":double quatation marks
#
#
# 2. What do the escape characters n and t stand for?
#
# ans:
#
# n stands for newline and t stands for tab
#
# 3. What is the way to include backslash characters in a string?
#
# ans:
#
# backslash are used as a escape characters so if we want to add the backslash characters we need to put two \\ so one backslash will wiped as a escape character and another one will be retained
#
# 4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?
#
# ans:
#
# different typing techniques are there in python to print strings
# we can use the triple quotes can print all the quotes in the strings. and we can use double quotes to print the single quotes in the print statement and vise versa
#
# 5. How do you write a string of newlines if you don't want to use the n character?
#
# ans:
#
# we can use os module in the module os.linesep .
# and the triple quote can be used.
#
# 6. What are the values of the given expressions?
# 'Hello, world!'[1]
# 'Hello, world!'[0:5]
# 'Hello, world!'[:5]
# 'Hello, world!'[3:]
#
#
# ans:
# 'Hello, world!'[1]=='e'
#
# 'Hello, world!'[0:5]='Hello'
#
# 'Hello, world!'[:5]='Hello'
#
# 'Hello, world!'[3:]='lo, world!'
#
# 7. What are the values of the following expressions?
# 'Hello'.upper()
# 'Hello'.upper().isupper()
# 'Hello'.upper().lower()
#
# ans:
# 'Hello'.upper()='HELLO'
# 'Hello'.upper().isupper()='True'
# 'Hello'.upper().lower()='hello'
#
#
# 8. What are the values of the following expressions?
# 'Remember, remember, the fifth of July'.split()
# '-'.join('There can only one.'.split())
#
# ans:
# 'Remember, remember, the fifth of July'.split()=['Remember,', 'remember,', 'the', 'fifth', 'of', 'July']
#
# '-'.join('There can only one.'.split())='There-can-only-one.'
#
# 9. What are the methods for right-justifying, left-justifying, and centering a string?
#
# ans:
#
# Right justifying will be done by using the rjust()function it creates the spaces in the left side.
#
# Left justifying will be done using ljust() it creates the spaces on the right side.
#
# centering string will use the center(), it creates spaces on both right and left side.
#
#
# 10. What is the best way to remove whitespace characters from the start or end?
#
# ans:
#
# we can use lstrip and rstrip()
